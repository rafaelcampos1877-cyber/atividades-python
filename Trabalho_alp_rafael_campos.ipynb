# %% [markdown]
# <a href="https://colab.research.google.com/github/rafaelcampos1877-cyber/atividades-python/blob/main/Trabalho_alp_rafael_campos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exercícios

# %%
numero = float(input("escreva um numero: "))
if numero % 2 == 0:
 print("par")
else:
 print("impar")
# Out:
# escreva um numero: 91
# impar

# %%
nota = float(input("escreva a nota do aluno: "))
if nota < 5:
 print("reprovado")
elif nota >= 5 and nota < 7:
 print("recuperação")
else:
 print("aprovado")
# Out:
# escreva a nota do aluno: 5.7
# recuperação

# %%
num1 = int(input("digite o primeiro numero: "))
num2 = int(input("digite o segundo numero: "))
num3 = int(input("digite o terceiro numero: "))
if num1 > num2 >num3:
 print("o maior é: ",num1)
elif num2 > num1 > num3:
 print("o maior é: ",num2)
else:
 print("o maior é: ",num3)
# Out:
# digite o primeiro numero: 23
# digite o segundo numero: 28
# digite o terceiro numero: 209
# o maior é:  209

# %%
N = int(input("digite um numero: "))
for i in range(1, N + 1):
 print(i)
# Out:
# digite um numero: 8
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
N = int(input("digite N: "))
soma = 0
for i in range(1, N + 1):
 soma += i
print("a soma é:", soma)
# Out:
# digite N: 7
# a soma é: 28

# %%
pares = 0
for i in range(10):
 numero = int(input("Digite um numero: "))
 if numero % 2 == 0:
  pares = pares + 1
print("Quantidade de numeros pares:", pares)
# Out:
# Digite um numero: 2
# Digite um numero: 1
# Digite um numero: 6
# Digite um numero: 87
# Digite um numero: 23
# Digite um numero: 45
# Digite um numero: 90
# Digite um numero: 88
# Digite um numero: 76
# Digite um numero: 52
# Quantidade de numeros pares: 6

# %%
soma = 0
for i in range(8):
 numero = int(input("Digite um numero: "))
 if numero > 0:
   soma = soma + numero
print("Soma dos positivos:", soma)
# Out:
# Digite um numero: 12
# Digite um numero: 23
# Digite um numero: 34
# Digite um numero: 45
# Digite um numero: 56
# Digite um numero: 67
# Digite um numero: 78
# Digite um numero: 89
# Soma dos positivos: 404

# %%
for i in [1, 2, 3, 4, 5, 6]:
 numero = int(input("Digite um numero: "))
 if i == 1:
  maior = numero
 if numero > maior:
  maior = numero
print("Maior valor:", maior)
# Out:
# Digite um numero: 78
# Digite um numero: 56
# Digite um numero: 45
# Digite um numero: 32
# Digite um numero: 14
# Digite um numero: 98
# Maior valor: 98

# %%
numero = int(input("Digite um numero: "))
for i in range(1, 11):
 resultado = numero * i
 print(numero, "x", i, "=", resultado)
# Out:
# Digite um numero: 78
# 78 x 1 = 78
# 78 x 2 = 156
# 78 x 3 = 234
# 78 x 4 = 312
# 78 x 5 = 390
# 78 x 6 = 468
# 78 x 7 = 546
# 78 x 8 = 624
# 78 x 9 = 702
# 78 x 10 = 780

# %%
senha = input("digite a senha: ")
while senha != "1234":
 senha = input("senha incorreta. Tente novamente: ")
print("acesso permitido!")
# Out:
# digite a senha: 1234
# acesso permitido!

# %%
secreto = 7
tentativas = 0
palpite = int(input("tente adivinhar o numero secreto: "))
tentativas = tentativas + 1
while palpite != secreto:
 if palpite < secreto:
   print("tente um número maior")
 else:
   print("Tente um número menor")
 palpite = int(input("digite outro numero: "))
 tentativas = tentativas + 1
print("parabéns! Você acertou.")
print("quantidade de tentativas:", tentativas)
# Out:
# tente adivinhar o numero secreto: 1
# tente um número maior
# digite outro numero: 20
# Tente um número menor
# digite outro numero: 10
# Tente um número menor
# digite outro numero: 5
# tente um número maior
# digite outro numero: 7
# parabéns! Você acertou.
# quantidade de tentativas: 5

# %%
total = 0
positivos = 0
negativos = 0
soma = 0
numero = int(input("digite um número: "))
while numero != 0:
 total = total + 1
 soma = soma + numero
 if numero > 0:
   positivos = positivos + 1
 else:
   negativos = negativos + 1
 numero = int(input("Digite um número: "))
print("quantidade:", total)
print("positivos:", positivos)
print("negativos:", negativos)
print("soma:", soma)
# Out:
# digite um número: 10
# Digite um número: 2099
# Digite um número: 77
# Digite um número: 89
# Digite um número: 0
# Quantidade: 4
# Positivos: 4
# Negativos: 0
# Soma: 2275
